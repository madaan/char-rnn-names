# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
def plot_length_dist(filename, name, facecolor):
    names = pd.read_csv(filename, header=None)
    names.columns = ["name"]
    
    names["length"] = names["name"].apply(lambda name: len(name))
    plt.hist(names["length"], bins=[i for i in range(30)], rwidth=0.9, facecolor=facecolor, alpha=0.75)
    plt.title("{0} Name Length Distribution".format(name))
    plt.xlabel("Length")
    plt.ylabel("#Names")
    plt.show()

# %%
plot_length_dist("../../data/indian_names.txt", name="Indian", facecolor='blue')
plot_length_dist("../../data/caucasian_names.txt", name="Caucasian", facecolor='orange')
plot_length_dist("../../data/african_american_names.txt", name="African American", facecolor='green')
plot_length_dist("../../data/hispanic_names.txt", name="Hispanic", facecolor='red')
plot_length_dist("../../data/all_races_names.txt", name="All Races", facecolor='pink')
